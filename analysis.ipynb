# %% [markdown]
# <a href="https://colab.research.google.com/github/lazeralien/harvestright_data/blob/main/analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # upload "batches.zip"

import os
if not os.path.exists("batches"):
    os.makedirs("batches")

# !unzip batches.zip -d batches

import glob, pandas as pd
csv_files = sorted(glob.glob("batches/*.csv"))

dataframes = []
for i, file in enumerate(csv_files, start=1):
    df = pd.read_csv(file)
    df["batch"] = i
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)
# Out:
#      <input type="file" id="files-e0462c85-dd16-4ad3-b7b3-04a887fb2d51" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e0462c85-dd16-4ad3-b7b3-04a887fb2d51">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
with pd.option_context('display.max_columns', None):
    display(combined_df.head())
# Out:
#    BQQ5DE5NO          TStamp  mTorr  HtrReq  HtrOn  Trays-J17  J19 J20  \
# 0       13.0  10/5/2023 9:14  78564       0      0         71   70  --
# 1       13.0  10/5/2023 9:15  71980       0      0         71   71  --
# 2       13.0  10/5/2023 9:16  71370       0      0         71   71  --
# 3       13.0  10/5/2023 9:17  66277       0      0         71   71  --
# 4       13.0  10/5/2023 9:18  63873       0      0         71   72  --
#
#   Room-J18    Process  Heater Relay  HeatCyc  VacCyc  mT~Hr  mT~Mid  LowF  \
# 0       --    Startup             0        0       0      0       0     0
# 1       --  Prefreeze             0        0       0      0       0    71
# 2       --  Prefreeze             0        0       0     11       6    71
# 3       --  Prefreeze             0        0       0     11       6    71
# 4       --  Prefreeze             0        0       0     11       6    71
#
#    v5.1.25d  SN= HR/A mT~50 HR/A/0 TmTyp=B    500    600    125      name  \
# ...
